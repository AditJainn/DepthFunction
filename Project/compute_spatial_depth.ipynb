# %%
import numpy as np
import itertools
import skfda
import matplotlib.pyplot as plt

# %%
# Allows us to get CRAN datasets
data = skfda.datasets.fetch_cran("MCO", "fda.usc")
data["MCO"]["intact"].plot()
plt.show()

# %%
# print (data["MCO"])

# %%
def difFunction (fdat, inds):
    return fdat[inds[0]] - fdat(inds[[1]])

# %%
def compuer_spatial_depth(fdat, N):
    #each col is a fn
    # mat=eval.fd(grid,fdat)
    pairs = list(itertools.combinations(range(N), 2))
    diffs = np.apply_along_axis(difFunction, 2, pairs)
